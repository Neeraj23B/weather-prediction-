# %% [markdown]
# # PROJECT TITLE : WEATHER PREDICTION

# %% [markdown]
# ## Scraping from API

# %%
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url1 = "http://api.openweathermap.org/data/2.5/forecast?lat=13.0827&lon=80.2707&cnt=200&appid=98e027721603ca32cead5457312b406a"
response1 = requests.get(url1)

# %%
json1 = response1.json()

# %%
data = json1['list']
data[0]
# Out:
# {'dt': 1696096800,
#  'main': {'temp': 302.35,
#   'feels_like': 308.92,
#   'temp_min': 301.88,
#   'temp_max': 302.35,
#   'pressure': 1010,
#   'sea_level': 1010,
#   'grnd_level': 1006,
#   'humidity': 82,
#   'temp_kf': 0.47},
#  'weather': [{'id': 500,
#    'main': 'Rain',
#    'description': 'light rain',
#    'icon': '10n'}],
#  'clouds': {'all': 60},
#  'wind': {'speed': 6.94, 'deg': 203, 'gust': 10.34},
#  'visibility': 10000,
#  'pop': 0.57,
#  'rain': {'3h': 1.02},
#  'sys': {'pod': 'n'},
#  'dt_txt': '2023-09-30 18:00:00'}

# %%
dt = []
temp = []
feels_like = []
temp_min = []
temp_max = []
pressure = []
sea_level = []
grnd_level = []
humidity = []
temp_kf = []
weather_id = []
weather_main = []
weather_description = []
weather_icon = []
clouds_all = []
wind_speed = []
wind_deg = []
wind_gust = []
visibility = []
pop = []
sys_pod = []
dt_txt = []
latitude = []
longitute = []
for i in range(len(data)):
    dt.append(data[i]['dt'])
    temp.append(data[i]['main']['temp'])
    feels_like.append(data[i]['main']['feels_like'])
    temp_min.append(data[i]['main']['temp_min'])
    temp_max.append(data[i]['main']['temp_max'])
    pressure.append(data[i]['main']['pressure'])
    sea_level.append(data[i]['main']['sea_level'])
    grnd_level.append(data[i]['main']['grnd_level'])
    humidity.append(data[i]['main']['humidity'])
    temp_kf.append(data[i]['main']['temp_kf'])
    weather_id.append(data[i]['weather'][0]['id'])
    weather_main.append(data[i]['weather'][0]['main'])
    weather_icon.append(data[i]['weather'][0]['icon'])
    clouds_all.append(data[i]['clouds']['all'])
    wind_speed.append(data[i]['wind']['speed'])
    wind_deg.append(data[i]['wind']['deg'])
    wind_gust.append(data[i]['wind']['gust'])
    visibility.append(data[i]['visibility'])
    pop.append(data[i]['pop'])
    sys_pod.append(data[i]['sys']['pod'])
    dt_txt.append(data[i]['dt_txt'])
    weather_description.append(data[i]['weather'][0]['description'])
    latitude.append(13.0827)
    longitute.append(80.2707)

# %%
d = {'dt': dt, 
     'latitude': latitude,
     'longitute': longitute,
     'temp': temp, 
     'feels_like': feels_like,
    'temp_min ':temp_min,
     'temp_max': temp_max, 
        'pressure':pressure,
     'sea_level': sea_level, 
     'grnd_level': grnd_level,
     'humidity': humidity,
       'temp_kf': temp_kf,
    'weather_id': weather_id,
    'weather_main': weather_main,
    'weather_icon': weather_icon,
    'clouds_all': clouds_all,
    'wind_speed': wind_speed,
    'wind_deg': wind_deg,
    'wind_gust': wind_gust,
    'visibility': visibility,
    'pop': pop,
    'sys_pod': sys_pod,
    'dt_txt': dt_txt,
     'weather_description': weather_description}
df = pd.DataFrame(data = d)

# %% [markdown]
# ## Creating a Dataframe

# %%
df
# Out:
#             dt  latitude  longitute    temp  feels_like  temp_min   temp_max  \
# 0   1696096800   13.0827    80.2707  302.35      308.92     301.88    302.35
# 1   1696107600   13.0827    80.2707  301.44      305.82     300.86    301.44
# 2   1696118400   13.0827    80.2707  300.68      302.72     300.68    300.68
# 3   1696129200   13.0827    80.2707  302.11      304.75     302.11    302.11
# 4   1696140000   13.0827    80.2707  304.43      308.34     304.43    304.43
# 5   1696150800   13.0827    80.2707  305.20      309.74     305.20    305.20
# 6   1696161600   13.0827    80.2707  302.50      307.29     302.50    302.50
# 7   1696172400   13.0827    80.2707  302.71      307.81     302.71    302.71
# 8   1696183200   13.0827    80.2707  301.81      305.84     301.81    301.81
# 9   1696194000   13.0827    80.2707  300.70      303.78     300.70    300.70
# 10  1696204800   13.0827    80.2707  300.27      302.30     300.27    300.27
# ...

# %%
# Check for null values
pd.isnull(df).sum()
# Out:
# dt                     0
# latitude               0
# longitute              0
# temp                   0
# feels_like             0
# temp_min               0
# temp_max               0
# pressure               0
# sea_level              0
# grnd_level             0
# humidity               0
# temp_kf                0
# weather_id             0
# weather_main           0
# weather_icon           0
# clouds_all             0
# wind_speed             0
# wind_deg               0
# wind_gust              0
# visibility             0
# pop                    0
# sys_pod                0
# dt_txt                 0
# weather_description    0
# dtype: int64

# %%
#Outcome Feature (Class) values
df['weather_description'].unique()
# Out:
# array(['light rain', 'overcast clouds', 'broken clouds'], dtype=object)

# %%
# Data Description
df.describe()
# Out:
#                  dt      latitude     longitute        temp  feels_like  \
# count  4.000000e+01  4.000000e+01  4.000000e+01   40.000000   40.000000
# mean   1.696307e+09  1.308270e+01  8.027070e+01  302.761000  306.507000
# std    1.262569e+05  8.994933e-15  1.439189e-14    1.754027    2.272998
# min    1.696097e+09  1.308270e+01  8.027070e+01  300.080000  302.300000
# 25%    1.696202e+09  1.308270e+01  8.027070e+01  301.635000  304.730000
# 50%    1.696307e+09  1.308270e+01  8.027070e+01  302.470000  306.565000
# 75%    1.696413e+09  1.308270e+01  8.027070e+01  303.372500  308.295000
# max    1.696518e+09  1.308270e+01  8.027070e+01  306.370000  310.500000
#
#         temp_min     temp_max     pressure    sea_level   grnd_level  \
# count   40.000000   40.000000    40.000000    40.000000    40.000000
# mean   302.734750  302.761000  1007.725000  1007.725000  1006.525000
# std      1.771832    1.754027     1.663908     1.663908     1.679247
# ...

# %%
#Checking Datatypes
df.dtypes
# Out:
# dt                       int64
# latitude               float64
# longitute              float64
# temp                   float64
# feels_like             float64
# temp_min               float64
# temp_max               float64
# pressure                 int64
# sea_level                int64
# grnd_level               int64
# humidity                 int64
# temp_kf                float64
# weather_id               int64
# weather_main            object
# weather_icon            object
# clouds_all               int64
# wind_speed             float64
# wind_deg                 int64
# wind_gust              float64
# visibility               int64
# pop                    float64
# sys_pod                 object
# dt_txt                  object
# weather_description     object
# dtype: object

# %%
df.isnull().values.any()
# Out:
# False

# %%
# Converting categorical to numerical values
df['weather_description'].replace(['light rain', 'overcast clouds', 'broken clouds'],
                        [1,2,3], inplace=True)

# %%
#Feature values
df['weather_icon'].unique()
# Out:
# array(['10n', '04n', '04d', '10d'], dtype=object)

# %%
# Converting categorical to numerical values
df['weather_icon'].replace(['10n', '04n', '04d', '10d'],
                        [0,1,2,3], inplace=True)

# %%
df.head(5)
# Out:
#            dt  latitude  longitute    temp  feels_like  temp_min   temp_max  \
# 0  1696096800   13.0827    80.2707  302.35      308.92     301.88    302.35
# 1  1696107600   13.0827    80.2707  301.44      305.82     300.86    301.44
# 2  1696118400   13.0827    80.2707  300.68      302.72     300.68    300.68
# 3  1696129200   13.0827    80.2707  302.11      304.75     302.11    302.11
# 4  1696140000   13.0827    80.2707  304.43      308.34     304.43    304.43
#
#    pressure  sea_level  grnd_level  ...  weather_icon  clouds_all  wind_speed  \
# 0      1010       1010        1006  ...             0          60        6.94
# 1      1008       1008        1005  ...             0          80        4.78
# 2      1007       1007        1006  ...             1         100        5.67
# 3      1009       1009        1008  ...             2         100        4.75
# 4      1008       1008        1007  ...             2         100        3.71
#
# ...

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ### Finding the count of Weather description(label value).

# %%
#  Count Plot
sns.countplot(x="weather_description",data=df)
# Out:
# <Axes: xlabel='weather_description', ylabel='count'>

# %% [markdown]
# ### Determining the pressure count.

# %%
sns.distplot(df['pressure'],color='black',bins=20,kde=False)
# Out:
# C:\Users\shamritha\AppData\Local\Temp\ipykernel_29936\1805508441.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['pressure'],color='black',bins=20,kde=False)
# <Axes: xlabel='pressure'>

# %% [markdown]
# ### Violin Plot between Sea Level and Humidity.

# %%
# Violin Plot
sns.violinplot(x='sea_level',y='humidity',data=df)
# Out:
# <Axes: xlabel='sea_level', ylabel='humidity'>

# %% [markdown]
# ### visualizing the distribution of Wind Speed and Density

# %%
sns.kdeplot(df['wind_speed'])
# Out:
# <Axes: xlabel='wind_speed', ylabel='Density'>

# %% [markdown]
# ## Model Building

# %%
from sklearn.model_selection import train_test_split

# %%
# Separating the Dependent and Independent Features
x=df[['latitude', 'longitute','temp', 'feels_like','temp_min ',
      'temp_max', 'pressure','sea_level', 'grnd_level',
      'humidity','weather_icon','wind_speed',
     'wind_deg','wind_gust','visibility','pop']]
y=df["weather_description"]

# %%
# x_train & y_train for Train the model
# x_test & y_test for Test/ Predict model
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
# Check train and test data shapes
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (32, 16)
# (8, 16)
# (32,)
# (8,)

# %% [markdown]
# ## SVM

# %%
from sklearn import svm

# %%
# Build SVM Classifier Model (Support Vector Classifier)
svc = svm.SVC(kernel= 'linear')

# %%
# Train Model
svc.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
# Predicting Outcome Class
y_pred = svc.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
# Confusion Matrix from predicted and actual class values
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix :")
print(cm)
# Out:
# Confusion Matrix :
# [[2 0]
#  [1 5]]

# %%
# Accuracy Score of Class prediction
acc=accuracy_score(y_test, y_pred)*100
print("Accuracy = ",acc,"%")
# Out:
# Accuracy =  87.5 %

# %%
# Comparision of Real and Predicted Class values
out = pd.DataFrame({'Real_class': y_test, 'Predicted_class': y_pred})
out.head(10)
# Out:
#     Real_class  Predicted_class
# 22           2                1
# 20           2                2
# 25           1                1
# 4            2                2
# 10           2                2
# 15           1                1
# 28           2                2
# 11           2                2

# %% [markdown]
# ## Logistic Regression

# %%
#Logistic Regression
from sklearn.linear_model import LogisticRegression
model = LogisticRegression ( solver = 'liblinear')
model.fit(x_train,y_train)
# Out:
# LogisticRegression(solver='liblinear')

# %%
pred = model.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
cn1 = confusion_matrix(y_test, pred)
ac1 = accuracy_score(y_test, pred)
cr1 = classification_report(y_test, pred)

# %%
print('Confusion Matrix :')
print(cn1)
# Out:
# Confusion Matrix :
# [[2 0]
#  [1 5]]

# %%
print('Accuracy:',ac1*100,'%')
# Out:
# Accuracy: 87.5 %

# %%
print('Classification Report:')
print(cr1)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.67      1.00      0.80         2
#            2       1.00      0.83      0.91         6
#
#     accuracy                           0.88         8
#    macro avg       0.83      0.92      0.85         8
# weighted avg       0.92      0.88      0.88         8

# %% [markdown]
# ## GaussianNB

# %%
#Naive Bayes
from sklearn.naive_bayes import GaussianNB
c=GaussianNB()
c.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_naive_pred=c.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
cn4 = confusion_matrix(y_test, y_naive_pred)
ac4 = accuracy_score(y_test, y_naive_pred)
cr4 = classification_report(y_test, y_naive_pred)

# %%
print('Confusion Matrix :')
print(cn4)
# Out:
# Confusion Matrix :
# [[2 0]
#  [1 5]]

# %%
print('Accuracy:',ac4*100,'%')
# Out:
# Accuracy: 87.5 %

# %%
print('Classification Report:')
print(cr4)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.67      1.00      0.80         2
#            2       1.00      0.83      0.91         6
#
#     accuracy                           0.88         8
#    macro avg       0.83      0.92      0.85         8
# weighted avg       0.92      0.88      0.88         8
